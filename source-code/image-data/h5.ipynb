# %% [markdown]
# ## Requirements

# %%
import h5py
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading data

# %% [markdown]
# Open the HDF5 file.

# %%
file = h5py.File('data/tmp_img_row_major.h5', 'r')

# %% [markdown]
# Check the shape of the dataset `data`.

# %%
file['data'].shape
# Out:
# (20, 648, 1152, 4)

# %% [markdown]
# Display the first image.

# %%
plt.imshow(file['data'][0]);

# %% [markdown]
# Display the last image.

# %%
plt.imshow(file['data'][-1]);

# %% [markdown]
# Close the HDF5 file.

# %%
file.close()
